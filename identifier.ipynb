# %%
#Identifier are user defined words.
#Identifier is a user defined word, which is used to identify pograming elements.
#1.variable name 
#2.Function name 
#3.Class name 
#4.Module name
#5.Package name
# Identifier is created using alphabet's (a-z,A-Z,0-9) and allows one special charcter ( _ ).

# %%
# Rule 1 identifier should not be a keyword.
# Error
break=1
# Out:
#   Cell In[19], line 3
#     break=1
#          ^
# SyntaxError: invalid syntax

# %%
# Correct
BREAK=1

# %%
# Rule 2 idintifier should not start with digit or it should start with alphabet.
# Error
2num=2
# Out:
#   Cell In[13], line 3
#     2num=2
#     ^
# SyntaxError: invalid decimal literal

# %%
# Correct
num2=2
print(num2)
# Out:
# 2

# %%
# Rule 3 There should not be any space in inentifier.
# Error
roll no=12
# Out:
#   Cell In[1], line 3
#     roll no=12
#          ^
# SyntaxError: invalid syntax

# %%
# Correct
roll_no=12
print(roll_no)
# Out:
# 12

# %%
# There is no restriction in length of identifier
aaaaaaaaaaaaaaaaaaaaaaaaaa=1
